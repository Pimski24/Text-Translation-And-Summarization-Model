# %%
# Install OpenNMT-py 3.x
# !pip3 install OpenNMT-py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.3/257.3 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.8/36.8 MB 46.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 84.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 14.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 71.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.8/110.8 kB 609.4 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 88.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.7/227.7 kB 27.3 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Open the folder where you saved your prepapred datasets from the first exercise
# You might need to mount your Google Drive first
# %cd /content/drive/MyDrive/nmt/
# !ls
# Out:
# /content/drive/MyDrive/nmt
# compute-bleu.py
# compute-bleu.py.1
# config.yaml
# en-nl.txt.zip
# JRC-Acquis.en-nl.en
# JRC-Acquis.en-nl.en-filtered.en
# JRC-Acquis.en-nl.en-filtered.en.subword
# JRC-Acquis.en-nl.en-filtered.en.subword.dev
# JRC-Acquis.en-nl.en-filtered.en.subword.test
# JRC-Acquis.en-nl.en-filtered.en.subword.test.desubword
# JRC-Acquis.en-nl.en-filtered.en.subword.train
# JRC-Acquis.en-nl.nl
# JRC-Acquis.en-nl.nl-filtered.nl
# JRC-Acquis.en-nl.nl-filtered.nl.subword
# JRC-Acquis.en-nl.nl-filtered.nl.subword.dev
# JRC-Acquis.en-nl.nl-filtered.nl.subword.test
# JRC-Acquis.en-nl.nl-filtered.nl.subword.train
# JRC-Acquis.en-nl.xml
# JRC-Acquis.en.translated
# JRC-Acquis.en.translated.desubword
# LICENSE
# models
# MT-Preparation
# README
# run
# source.model
# source.vocab
# target.model
# target.vocab
# train.log

# %%
# [Optional] Check the content of the configuration file
# !cat config.yaml
# Out:
# # config.yaml
#
#
# ## Where the samples will be written
# save_data: run
#
# # Training files
# data:
#     corpus_1:
#         path_src: JRC-Acquis.en-nl.nl-filtered.nl.subword.train
#         path_tgt: JRC-Acquis.en-nl.en-filtered.en.subword.train
#         transforms: [filtertoolong]
#     valid:
#         path_src: JRC-Acquis.en-nl.nl-filtered.nl.subword.dev
#         path_tgt: JRC-Acquis.en-nl.en-filtered.en.subword.dev
#         transforms: [filtertoolong]
#
# # Vocabulary files, generated by onmt_build_vocab
# src_vocab: run/source.vocab
# tgt_vocab: run/target.vocab
#
# # Vocabulary size - should be the same as in sentence piece
# src_vocab_size: 50000
# tgt_vocab_size: 50000
#
# # Filter out source/target longer than n if [filtertoolong] enabled
# src_seq_length: 150
# src_seq_length: 150
#
# # Tokenization options
# src_subword_model: source.model
# tgt_subword_model: target.model
#
# # Where to save the log file and the output models/checkpoints
# log_file: train.log
# ...

# %%
# Check if the GPU is active
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-b7647b4a-f69c-84f2-6ec3-cdb696aa2eb4)

# %%
# Check if the GPU is visable to PyTorch

import torch

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))

gpu_memory = torch.cuda.mem_get_info(0)
print("Free GPU memory:", gpu_memory[0]/1024**2, "out of:", gpu_memory[1]/1024**2)
# Out:
# True
# Tesla T4
# Free GPU memory: 14998.8125 out of: 15101.8125

# %%
# Translate the "subworded" source file of the test dataset
# Change the model name, if needed.
# !onmt_translate -model models/model.fren_step_15000.pt -src JRC-Acquis.en-nl.nl-filtered.nl.subword.test -output JRC-Acquis.en.translated -gpu 0 -min_length 1
# Out:
# 2023-11-20 20:53:09.254515: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-20 20:53:09.254592: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-20 20:53:09.254632: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-20 20:53:09.262342: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# Check the first 5 lines of the translation file
# !head -n 5 JRC-Acquis.en.translated
# Out:
# ▁( 3 0 ) ▁In ▁order ▁to <unk> <unk> ▁use , ▁it <unk> ▁be <unk> ▁to <unk> ▁the <unk> <unk> ▁under ▁the <unk> ▁of ▁the ▁Community <unk> ▁or <unk> <unk>
# ▁( 7 ) ▁Un less <unk> <unk> ▁in ▁the <unk> <unk> , <unk> <unk> ▁not <unk> <unk> ▁against ▁the ▁Office ▁when ▁the ▁death ▁of ▁the <unk> <unk>
# ▁( i ) <unk> ▁from ▁a <unk> <unk> ▁whose <unk> ▁authority ▁must <unk> ▁registration <unk> ▁the <unk> ▁of ▁Article ▁ 4 ▁no <unk> <unk> <unk>
# ▁If , ▁within ▁three <unk> ▁of ▁the ▁date ▁of <unk> ▁to ▁the ▁Council , ▁the ▁Council ▁has ▁not <unk> , ▁the <unk> <unk> <unk> ▁be <unk> ▁by ▁the ▁Commission <unk>
# ▁( 9 ) ▁Some ▁technical <unk> <unk> ▁be <unk> ▁in ▁order ▁to <unk> <unk> ▁in ▁and ▁between ▁the ▁different ▁language <unk> ▁of ▁the <unk> <unk>

# %%
# If needed install/update sentencepiece
# !pip3 install --upgrade -q sentencepiece

# Desubword the translation file
# !python3 MT-Preparation/subwording/3-desubword.py target.model JRC-Acquis.en.translated
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 10.9 MB/s eta 0:00:00
# Done desubwording! Output: JRC-Acquis.en.translated.desubword

# %%
# Check the first 5 lines of the desubworded translation file
# !head -n 5 JRC-Acquis.en.translated.desubword
# Out:
# (30) In order to ⁇  ⁇  use, it ⁇  be ⁇  to ⁇  the ⁇  ⁇  under the ⁇  of the Community ⁇  or ⁇  ⁇
# (7) Unless ⁇  ⁇  in the ⁇  ⁇ , ⁇  ⁇  not ⁇  ⁇  against the Office when the death of the ⁇  ⁇
# (i) ⁇  from a ⁇  ⁇  whose ⁇  authority must ⁇  registration ⁇  the ⁇  of Article 4 no ⁇  ⁇  ⁇
# If, within three ⁇  of the date of ⁇  to the Council, the Council has not ⁇ , the ⁇  ⁇  ⁇  be ⁇  by the Commission ⁇
# (9) Some technical ⁇  ⁇  be ⁇  in order to ⁇  ⁇  in and between the different language ⁇  of the ⁇  ⁇

# %%
# Install sacrebleu
# !pip3 install sacrebleu

# %%
# Evaluate the translation (without subwording)
# !python3 compute-bleu.py JRC-Acquis.en-nl.en-filtered.en.subword.test.desubword JRC-Acquis.en.translated.desubword
# Out:
# Reference 1st sentence: (30) It may be necessary to monitor the computer networks operated under the control of the Community institutions and bodies for the purposes of prevention of unauthorised use.
# MTed 1st sentence: (30) In order to ⁇  ⁇  use, it ⁇  be ⁇  to ⁇  the ⁇  ⁇  under the ⁇  of the Community ⁇  or ⁇  ⁇
# BLEU:  27.98138619313297
