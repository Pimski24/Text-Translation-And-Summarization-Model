# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Install the requirements
# !pip3 install -r drive/MyDrive/nmt/MT-Preparation/requirements.txt
# Install OpenNMT-py 3.x
# !pip3 install OpenNMT-py
# Install sacrebleu
# !pip3 install sacrebleu
# If needed install/update sentencepiece
# !pip3 install --upgrade -q sentencepiece
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.3/257.3 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.8/36.8 MB 46.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 93.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 16.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 26.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.8/110.8 kB 16.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 101.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.7/227.7 kB 30.0 MB/s eta 0:00:00
# ...

# %%
# Train a SentencePiece model for subword tokenization
# %cd drive/MyDrive/nmt
# !python3 MT-Preparation/subwording/1-train_unigram.py solar-power.nl.txt JRC-Acquis.en-nl.en-filtered.en
# Out:
# /content/drive/MyDrive/nmt
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=solar-power.nl.txt --model_prefix=source --vocab_size=50000 --hard_vocab_limit=false --split_digits=true
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: solar-power.nl.txt
#   input_format:
#   model_prefix: source
#   model_type: UNIGRAM
#   vocab_size: 50000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 1
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
# ...

# %%
# Subword the dataset
# !python3 MT-Preparation/subwording/2-subword.py source.model target.model solar-power.nl.txt JRC-Acquis.en-nl.en-filtered.en
# Out:
# Source Model: source.model
# Target Model: target.model
# Source Dataset: solar-power.nl.txt
# Target Dataset: JRC-Acquis.en-nl.en-filtered.en
# Done subwording the source file! Output: solar-power.nl.txt.subword
# Done subwording the target file! Output: JRC-Acquis.en-nl.en-filtered.en.subword

# %%
# First 3 lines before subwording
# !head -n 3 solar-power.nl.txt && echo "-----" && head -n 3 JRC-Acquis.en-nl.en-filtered.en
# Out:
# In de afgelopen jaren heeft de wereldwijde beweging naar duurzame energieoplossingen aanzienlijke momentum gekregen, waarbij zonne-energie naar voren komt als een koploper in de race naar een groenere toekomst. Deze paradigmaverschuiving wordt aangedreven door vooruitgang in fotovoltaïsche technologie, waardoor zonne-energie toegankelijker en kosteneffectiever wordt. Het artikel onderzoekt de diepgaande invloed van zonne-energie op het energielandschap, waarbij de nadruk ligt op het potentieel om klimaatverandering tegen te gaan en de afhankelijkheid van fossiele brandstoffen te verminderen.
#
# ...

# %%
# First 3 lines after subwording
# !head -n 3 solar-power.nl.txt.subword && echo "---" && head -n 3 JRC-Acquis.en-nl.en-filtered.en.subword
# Out:
# ▁ I n ▁de ▁af ge lope n ▁ j ar en ▁he ef t ▁de ▁w er eld w ij de ▁be we ging ▁na ar ▁ du u rz a me ▁energie oplo ssingen ▁aan zien lijke ▁m o ment u m ▁gek rege n , ▁waar b ij ▁zonne - energie ▁na ar ▁vo ren ▁ kom t ▁ al s ▁e en ▁k oplo per ▁in ▁de ▁r ac e ▁na ar ▁e en ▁gro ener e ▁toekomst . ▁D e z e ▁p ar ad ig ma ver sch ui v ing ▁wordt ▁aan ge d re ven ▁d oor ▁voor uit g an g ▁in ▁fo t ov ol ta ï sch e ▁ technologie , ▁waar d oor ▁zonne - energie ▁toe g ankelijk er ▁en ▁ kosten eff ec tie ver ▁wordt . ▁ H et ▁ ar ti kel ▁onderzo ek t ▁de ▁die p gaan de ▁in v lo ed ▁v an ▁zonne - energie ▁op ▁he t ▁energie l and scha p , ▁waar b ij ▁de ▁ nadruk ▁ lig t ▁op ▁he t ▁p ot en tie el ▁ om ▁k li maat ver and ering ▁te gen ▁te ▁ gaan ▁en ▁de ▁af h ankelijk heid ▁v an ▁fo ssi ele ▁b rand s to ff en ▁te ▁ver mi nder en .
#
# ...

# %% [markdown]
# **Translation part**

# %%
# Check if the GPU is active
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-a5b432eb-0dad-0b1d-fd54-acb269b31273)

# %%
# Check if the GPU is visable to PyTorch

import torch

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))

gpu_memory = torch.cuda.mem_get_info(0)
print("Free GPU memory:", gpu_memory[0]/1024**2, "out of:", gpu_memory[1]/1024**2)
# Out:
# True
# Tesla T4
# Free GPU memory: 14998.8125 out of: 15101.8125

# %%
# Translate the "subworded" source file of the test dataset
# Change the model name, if needed.
# !onmt_translate -model models/model.fren_step_15000.pt -src solar-power.nl.txt.subword -output solar-power.translated -gpu 0 -min_length 1
# Out:
# 2023-11-27 11:16:22.235326: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-27 11:16:22.235387: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-27 11:16:22.235442: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-27 11:16:22.247905: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# This one is just for reference
# Check the first 5 lines of the translation file
# !head -n 5 solar-power.translated
# Out:
# ▁ <unk> ▁the <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> ▁in ▁the <unk> ▁after <unk> <unk> n <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk>
# ...

# %%
# Desubword the translation file
# !python3 MT-Preparation/subwording/3-desubword.py target.model solar-power.translated
# Check the first 5 lines of the desubworded translation file
# !head -n 5 solar-power.translated.desubword
# Out:
# Done desubwording! Output: solar-power.translated.desubword

# %% [markdown]
# **BLEU score Evaluation**

# %%
# Evaluate the translation (without subwording)
# !python3 compute-bleu.py solar-power.en.txt solar-power.translated.desubword
# Out:
# Reference 1st sentence: In recent years, the global push towards sustainable energy solutions has gained significant momentum, with solar power emerging as a frontrunner in the race towards a greener future. This paradigm shift is fueled by advancements in photovoltaic technology, making solar energy more accessible and cost-effective. The article explores the profound impact of solar power on the energy landscape, highlighting its potential to mitigate climate change and reduce dependence on fossil fuels.
# MTed 1st sentence: ⁇  the ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  in the ⁇  after ⁇  ⁇ n ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇  ⁇
# BLEU:  0.2545004384235765
